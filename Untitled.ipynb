# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('C:/Users/adish/Desktop/klklj/TESS Toronto emotional speech set data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:4]
# Out:
# ['C:/Users/adish/Desktop/klklj/TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'C:/Users/adish/Desktop/klklj/TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'C:/Users/adish/Desktop/klklj/TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'C:/Users/adish/Desktop/klklj/TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech  label
# 0  C:/Users/adish/Desktop/klklj/TESS Toronto emot...  angry
# 1  C:/Users/adish/Desktop/klklj/TESS Toronto emot...  angry
# 2  C:/Users/adish/Desktop/klklj/TESS Toronto emot...  angry
# 3  C:/Users/adish/Desktop/klklj/TESS Toronto emot...  angry
# 4  C:/Users/adish/Desktop/klklj/TESS Toronto emot...  angry

# %%
df['label'].value_counts()
# Out:
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: label, dtype: int64

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveplot(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 4>()
#       2 path = np.array(df['speech'][df['label']==emotion])[0]
#       3 data, sampling_rate = librosa.load(path)
# ----> 4 waveplot(data, sampling_rate, emotion)
#       5 spectogram(data, sampling_rate, emotion)
#       6 Audio(path)
#
# Input In [10], in waveplot(data, sr, emotion)
#       2 plt.figure(figsize=(10,4))
#       3 plt.title(emotion, size=20)
# ----> 4 librosa.display.waveplot(data, sr=sr)
#       5 plt.show()
#
# AttributeError: module 'librosa.display' has no attribute 'waveplot'

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
# waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
# waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
# waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.9791476e+02,  7.8756226e+01, -2.0911753e+01, -2.0349020e+01,
#        -3.4199812e+00,  1.1357657e+01, -2.1622477e+01, -4.8617826e+00,
#        -8.4185266e+00,  6.2100196e-01, -2.9795790e+00,  1.3149230e+00,
#        -3.4300953e-01,  2.3402820e+00,  1.9168801e+00,  3.7745941e+00,
#        -5.5863881e+00, -3.6113353e+00, -2.3929300e+00, -9.5256548e+00,
#        -8.2061357e+00, -1.2038866e+00, -7.5688171e+00,  9.9129763e+00,
#         7.9321532e+00,  2.2083347e+01,  1.8905153e+01,  2.0599804e+01,
#         1.3219537e+01,  8.4827595e+00,  3.0294445e-01,  5.1541729e+00,
#         9.5726032e+00,  5.4089766e+00,  2.6034532e+00, -1.9647242e+00,
#         5.0509210e+00,  9.0977497e+00,  2.3394349e+00, -2.1917243e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-397.91476, 78.756226, -20.911753, -20.34902,...
# 1       [-466.53455, 99.911064, -0.480273, -31.616299,...
# 2       [-431.5178, 48.56504, -0.8924488, 2.2234004, 0...
# 3       [-405.01205, 78.51893, -14.72178, -20.10229, -...
# 4       [-435.3804, 79.39025, 8.873595, 18.061928, 6.0...
#                               ...
# 2795    [-554.5794, 91.78299, 25.282017, 18.345247, 17...
# 2796    [-590.1003, 97.41461, 35.74892, 16.209633, 27....
# 2797    [-535.2709, 88.06032, 25.163685, 21.924894, 19...
# 2798    [-549.7413, 111.764175, 30.308115, 14.165436, ...
# 2799    [-550.9464, 104.709015, 29.937454, 28.579796, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305,799
# Trainable params: 305,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 5s 96ms/step - loss: 1.1004 - accuracy: 0.6152 - val_loss: 1.2117 - val_accuracy: 0.3964
# Epoch 2/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.3912 - accuracy: 0.8594 - val_loss: 0.3910 - val_accuracy: 0.8804
# Epoch 3/50
# 35/35 [==============================] - 3s 96ms/step - loss: 0.2198 - accuracy: 0.9277 - val_loss: 0.3597 - val_accuracy: 0.8875
# Epoch 4/50
# 35/35 [==============================] - 4s 114ms/step - loss: 0.1380 - accuracy: 0.9607 - val_loss: 0.1056 - val_accuracy: 0.9607
# Epoch 5/50
# 35/35 [==============================] - 4s 107ms/step - loss: 0.1062 - accuracy: 0.9652 - val_loss: 0.1346 - val_accuracy: 0.9554
# Epoch 6/50
# 35/35 [==============================] - 4s 105ms/step - loss: 0.0864 - accuracy: 0.9741 - val_loss: 0.2306 - val_accuracy: 0.9196
# Epoch 7/50
# 35/35 [==============================] - 4s 117ms/step - loss: 0.0947 - accuracy: 0.9683 - val_loss: 0.0378 - val_accuracy: 0.9893
# Epoch 8/50
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0816 - accuracy: 0.9705 - val_loss: 0.0771 - val_accuracy: 0.9696
# Epoch 9/50
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0809 - accuracy: 0.9754 - val_loss: 0.1323 - val_accuracy: 0.9464
# Epoch 10/50
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0785 - accuracy: 0.9795 - val_loss: 0.0686 - val_accuracy: 0.9750
- val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 32/50
# 35/35 [==============================] - 4s 103ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 33/50
# 35/35 [==============================] - 3s 99ms/step - loss: 0.0110 - accuracy: 0.9973 - val_loss: 0.0029 - val_accuracy: 0.9982
# Epoch 34/50
# 35/35 [==============================] - 3s 98ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 0.0117 - val_accuracy: 0.9946
# Epoch 35/50
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0335 - accuracy: 0.9906 - val_loss: 0.0619 - val_accuracy: 0.9821
# Epoch 36/50
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0355 - accuracy: 0.9897 - val_loss: 0.1165 - val_accuracy: 0.9661
# Epoch 37/50
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0622 - accuracy: 0.9812 - val_loss: 0.0311 - val_accuracy: 0.9857
# Epoch 38/50
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 39/50
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.1101 - val_accuracy: 0.9643
# Epoch 40/50
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0186 - accuracy: 0.9929 - val_loss: 0.0208 - val_accuracy: 0.9964
# Epoch 41/50
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 4.0106e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0146 - accuracy: 0.9978 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 43/50
# 35/35 [==============================] - 4s 115ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.0044 - val_accuracy: 0.9982
# Epoch 44/50
# 35/35 [==============================] - 4s 127ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0020 - val_accuracy: 0.9982
# Epoch 45/50
# 35/35 [==============================] - 4s 110ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 7.5993e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 35/35 [==============================] - 4s 107ms/step - loss: 0.0749 - accuracy: 0.9839 - val_loss: 0.0220 - val_accuracy: 0.9929
# Epoch 47/50
# 35/35 [==============================] - 4s 119ms/step - loss: 0.0313 - accuracy: 0.9911 - val_loss: 0.0425 - val_accuracy: 0.9804
# Epoch 48/50
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0471 - accuracy: 0.9888 - val_loss: 0.0289 - val_accuracy: 0.9893
# Epoch 49/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 0.0590 - val_accuracy: 0.9857
# Epoch 50/50
# 35/35 [==============================] - 3s 99ms/step - loss: 0.0422 - accuracy: 0.9929 - val_loss: 0.0034 - val_accuracy: 1.0000

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
